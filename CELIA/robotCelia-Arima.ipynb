# %%
#!/usr/bin/env python
# coding: utf-8

import numpy as np
import sys
import pandas as pd

# %%
dataPred = pd.read_csv("../Prediction_Files/arimaPrediction.csv")

# %% [markdown]
# # reading predictions and transforming data

# %%
# dataPred.Hours = ((dataPred.Hours)*23)+0
# dataPred.Minutes = ((dataPred.Minutes)*59)+0
# dataPred.Seconds = ((dataPred.Seconds)*59.999805)+0.102506

# %%
# def rowToTime(row):
#     timeAtMoment = row.Hours*3600*1000
#     timeAtMoment += row.Minutes*60*1000
#     timeAtMoment += row.Seconds*1000
#     return timeAtMoment

# %%
# resetAddTime = 23*3600*1000
# resetAddTime += 59*60*1000
# resetAddTime += 60*1000

# %%
dataPred
# Out:
#      TimestampReal  Server  Tactic    Latency  Cost  Reliability  \
# 0          37:16.6       3       3   0.022856  22.2            1
# 1          37:53.5       3       4  36.884413  25.4            1
# 2          37:53.7       3       5   0.259813  25.2            1
# 3          39:06.0       4       1  28.226795   2.7            1
# 4          39:08.0       4       2   2.046660  25.0            1
# 5          39:08.1       4       3   0.025759  30.0            1
# 6          39:49.0       4       4  40.897286  25.2            1
# 7          39:49.3       4       5   0.294206  24.8            1
# 8          40:30.9       5       1  25.086292   3.1            1
# 9          40:32.7       5       2   1.859253  25.3            1
# 10         40:32.8       5       3   0.021563  22.2            1
# 11         41:09.5       5       4  36.715894  25.6            1
# 12         41:09.7       5       5   0.251645  24.8            1
# 13         41:44.3       6       1  17.537968   4.4            1
# 14         41:46.1       6       2   1.803503  25.3            1
# 15         41:46.2       6       3   0.025734  27.3            1
# 16         42:25.2       6       4  39.042529  25.0            1
# 17         42:26.0       6       5   0.773975   9.8            1
# 18         42:40.4       7       1   7.535057   9.0            1
# 19         42:42.4       7       2   1.972670  25.0            1
# 20         42:42.4       7       3   0.027481  25.0            1
# 21         43:19.4       7       4  36.984505  25.7            1
# 22         43:19.7       7       5   0.271009  25.0            1
# 23         43:58.9       8       1  19.811841   5.0            1
# 24         44:00.9       8       2   1.955453  25.1            1
# 25         44:00.9       8       3   0.025177  36.4            1
# 26         44:37.6       8       4  36.671828  25.3            1
# 27         44:37.9       8       5   0.282628  25.4            1
# 28         45:10.9       1       1  15.552752   3.2            1
# 29         45:13.0       1       2   2.038089  25.0            1
# ...            ...     ...     ...        ...   ...          ...
# 5720       13:18.7       6       4  38.524212  25.4            1
# 5721       13:18.9       6       5   0.264917  50.0            1
# 5722       13:47.8       7       1  14.583041   4.8            1
# 5723       13:49.8       7       2   1.942172  25.2            1
# 5724       13:49.8       7       3   0.025313  20.0            1
# 5725       14:27.1       7       4  37.265126  25.3            1
# 5726       14:27.3       7       5   0.242338  25.0            1
# 5727       15:07.2       8       1  19.722372   4.8            1
# 5728       15:09.1       8       2   1.790424  25.0            1
# 5729       15:09.1       8       3   0.021706  22.2            1
# 5730       15:47.5       8       4  38.433380  25.7            1
# 5736        0.498911    21.894967     600511                1
# 5737       14.300000     8.170000     600532                1
# 5738        1.901374    25.325956     600534                1
# 5739        0.024374    25.676633     600534                1
# 5740       39.896080    25.360180     600574                1
# 5741        0.498911    21.894967     600574                1
# 5742        5.110000    28.900000     600580                1
# 5743        1.901374    25.325956     600581                1
# 5744        0.024374    25.676633     600581                1
# 5745       39.896080    25.360180     600618                1
# 5746        0.498911    21.894967     600618                1
# 5747       25.200000     6.820000     600678                1
# 5748        1.901374    25.325956     600680                1
# 5749        0.024374    25.676633     600680                1
#
# [5750 rows x 10 columns]

# %% [markdown]
# ### this is converting hours, minutes, seconds to a millisecond time series

# %%
# cumulativeTime = [rowToTime(dataPred.iloc[0])]

# for i in range(1,len(dataPred)):
#     timeAtMoment = rowToTime(dataPred.iloc[i])
#     lastTimeMoment = rowToTime(dataPred.iloc[i-1])
#     if timeAtMoment > lastTimeMoment:
#         cumuTime = cumulativeTime[i-1] + (timeAtMoment - lastTimeMoment)
#         cumulativeTime.append(cumuTime)
#     else:
#         cumulativeTime.append(cumulativeTime[i-1]+(timeAtMoment+resetAddTime)-lastTimeMoment)
# #         print(cumulativeTime[i])

# %%
# cumulativeTime = cumulativeTime- cumulativeTime[0]
# cumulativeTime

# %%
dataPred.Timestamp = dataPred.Timestamp - dataPred.Timestamp.min()

# %%
dataPred
# Out:
#      TimestampReal  Server  Tactic    Latency  Cost  Reliability  \
# 0          37:16.6       3       3   0.022856  22.2            1
# 1          37:53.5       3       4  36.884413  25.4            1
# 2          37:53.7       3       5   0.259813  25.2            1
# 3          39:06.0       4       1  28.226795   2.7            1
# 4          39:08.0       4       2   2.046660  25.0            1
# 5          39:08.1       4       3   0.025759  30.0            1
# 6          39:49.0       4       4  40.897286  25.2            1
# 7          39:49.3       4       5   0.294206  24.8            1
# 8          40:30.9       5       1  25.086292   3.1            1
# 9          40:32.7       5       2   1.859253  25.3            1
# 10         40:32.8       5       3   0.021563  22.2            1
# 11         41:09.5       5       4  36.715894  25.6            1
# 12         41:09.7       5       5   0.251645  24.8            1
# 13         41:44.3       6       1  17.537968   4.4            1
# 14         41:46.1       6       2   1.803503  25.3            1
# 15         41:46.2       6       3   0.025734  27.3            1
# 16         42:25.2       6       4  39.042529  25.0            1
# 17         42:26.0       6       5   0.773975   9.8            1
# 18         42:40.4       7       1   7.535057   9.0            1
# 19         42:42.4       7       2   1.972670  25.0            1
# 20         42:42.4       7       3   0.027481  25.0            1
# 21         43:19.4       7       4  36.984505  25.7            1
# 22         43:19.7       7       5   0.271009  25.0            1
# 23         43:58.9       8       1  19.811841   5.0            1
# 24         44:00.9       8       2   1.955453  25.1            1
# 25         44:00.9       8       3   0.025177  36.4            1
# 26         44:37.6       8       4  36.671828  25.3            1
# 27         44:37.9       8       5   0.282628  25.4            1
# 5720       39.896080    25.360180     124562                1
# 5721        0.498911    21.894967     124562                1
# 5722        9.450000    12.100000     124591                1
# 5723        1.901374    25.325956     124593                1
# 5724        0.024374    25.676633     124593                1
# 5725       39.896080    25.360180     124630                1
# 5726        0.498911    21.894967     124630                1
# 5727       25.200000     6.820000     124670                1
# 5728        1.901374    25.325956     124672                1
# 5729        0.024374    25.676633     124672                1
# 5730       39.896080    25.360180     124711                1
# 5731        0.498911    21.894967     124711                1
# 5732       19.800000     4.160000     124758                1
# 5733        1.901374    25.325956     124759                1
# 5734        0.024374    25.676633     124759                1
# 5735       39.896080    25.360180     124796                1
# 5736        0.498911    21.894967     124796                1
# 5737       14.300000     8.170000     124817                1
# 5738        1.901374    25.325956     124819                1
# 5739        0.024374    25.676633     124819                1
# 5740       39.896080    25.360180     124859                1
# 5741        0.498911    21.894967     124859                1
# 5742        5.110000    28.900000     124865                1
# 5743        1.901374    25.325956     124866                1
# 5744        0.024374    25.676633     124866                1
# 5745       39.896080    25.360180     124903                1
# 5746        0.498911    21.894967     124903                1
# 5747       25.200000     6.820000     124963                1
# 5748        1.901374    25.325956     124965                1
# 5749        0.024374    25.676633     124965                1
#
# [5750 rows x 10 columns]

# %% [markdown]
# ### shifting and transforming data to a range of 0-50

# %%
def shiftTransformCol50(data):
#     return (data + abs(data.min()))*50
    return data

# %%
# newData = np.stack((cumulativeTime, shiftTransformCol50(dataPred.Latency), shiftTransformCol50(dataPred.Cost), dataPred.Reliability, shiftTransformCol50(dataPred.predicted_Latency), shiftTransformCol50(dataPred.predicted_Cost), round(dataPred.predicted_Reliability)),axis = 1)
# newData = np.stack((dataPred.Timestamp, shiftTransformCol50(dataPred.Latency), shiftTransformCol50(dataPred.Cost), dataPred.Reliability, shiftTransformCol50(dataPred.predicted_Latency), shiftTransformCol50(dataPred.predicted_Cost), round(dataPred.predicted_Reliability)),axis = 1)

# newData = pd.DataFrame(newData, columns=['Timestamp', 'Latency', 'Cost', 'Reliability', 'predLatency', 'predCost', 'predReliability' ])

# %%
newData.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-d961d91cec68> in <module>
# ----> 1 newData.describe()
#
# NameError: name 'newData' is not defined

# %%
data = dataPred

# %%
def utilFunction(latency, cost, reward = 100, reliability = 1):
    epsilon = 0.00000000000000000000000000000000000000000000001

    if reliability == 0:
        return 0
    else:
        return ((reward)/(latency+cost+epsilon)) * reliability

# %% [markdown]
# realUtilityMean = 4.138921e+06
# realUtilStd = 6.175693e+06

# %%
lastUpdate = 0;
updateThreshold = 1000
utilitPredicted = []
utilityReal = []
award = []
lostUtility = []

# %%
# real time utility aware analysis tool

# %%
temp = data.iloc[1]['Timestamp'] - data.iloc[0]['Timestamp']
# type(temp.total_seconds())
# pd.to_datetime(data.iloc[1]['Timestamp'] - data.iloc[0]['Timestamp'], unit='ms')

# %%
for i in range(1,len(data)):
#     timeDeltaReward = (data.iloc[i]['Timestamp'] - data.iloc[i-1]['Timestamp']).total_seconds()
    timeDeltaReward = (data.iloc[i]['Timestamp'] - data.iloc[i-1]['Timestamp'])

    predictedUtil = utilFunction(data.iloc[i].predLatency, data.iloc[i].predCost,(float)(timeDeltaReward), data.iloc[i].predReliability )
    
    realUtility = utilFunction(data.iloc[i].Latency, data.iloc[i].Cost,(float)(timeDeltaReward), data.iloc[i].Reliability )
    utilitPredicted.append(predictedUtil)
    utilityReal.append(realUtility)
    if predictedUtil >= updateThreshold:
#         award.append(award[i-1] + realUtility-1);
        award.append(realUtility-updateThreshold);
        lostUtility.append(0)
    else:
#         award.append(award[i-1]);
        award.append(0);
    
        if realUtility >= updateThreshold:
            lostUtility.append(realUtility)
        else:
            lostUtility.append(0)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-dd32b2aba822> in <module>
#       3     timeDeltaReward = (data.iloc[i]['Timestamp'] - data.iloc[i-1]['Timestamp'])
#       4
# ----> 5     predictedUtil = utilFunction(data.iloc[i].predLatency, data.iloc[i].predCost,(float)(timeDeltaReward), data.iloc[i].predReliability )
#       6
#       7     realUtility = utilFunction(data.iloc[i].Latency, data.iloc[i].Cost,(float)(timeDeltaReward), data.iloc[i].Reliability )
#
# /usr/local/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'predLatency'

# %%
results = pd.DataFrame(np.stack([utilitPredicted,utilityReal,award,lostUtility],axis=1),columns=['predictedUtility','realUtility','award','lostUtility'])

# %%
results
# Out:
#        predictedUtility   realUtility         award  lostUtility
# 0          7.415394e+01  1.072988e+02  0.000000e+00     0.000000
# 1          1.244738e+00  1.943731e+00  0.000000e+00     0.000000
# 2          1.970427e+03  2.033319e+03  1.033319e+03     0.000000
# 3          1.262597e+01  1.527865e+01  0.000000e+00     0.000000
# 4          1.809172e+03  1.037093e+04  9.370930e+03     0.000000
# 5          8.186739e+01  1.234220e+02  0.000000e+00     0.000000
# 6          1.663543e+00  2.064515e+00  0.000000e+00     0.000000
# 7          2.085351e+03  2.002638e+03  1.002638e+03     0.000000
# 8          1.624122e+01  1.535870e+01  0.000000e+00     0.000000
# 9          1.350132e+03  7.833239e+03  6.833239e+03     0.000000
# 10         7.720382e+01  1.152469e+02  0.000000e+00     0.000000
# 11         1.062641e+00  1.389032e+00  0.000000e+00     0.000000
# 12         2.070459e+03  1.998719e+03  9.987192e+02     0.000000
# 13         1.706620e+01  1.552609e+01  0.000000e+00     0.000000
# 14         1.548154e+03  7.603407e+03  6.603407e+03     0.000000
# 15         8.299933e+01  1.230867e+02  0.000000e+00     0.000000
# 16         1.364602e+00  1.744301e+00  0.000000e+00     0.000000
# 17         2.255536e+03  2.037675e+03  1.037675e+03     0.000000
# 18         6.835062e+01  5.378251e+01  0.000000e+00     0.000000
# 19         6.072526e+02  2.095871e+03  0.000000e+00  2095.871280
# 20         7.610830e+01  1.094633e+02  0.000000e+00     0.000000
