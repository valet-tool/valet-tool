# %%
import array
import pandas
import numpy
import math

# %%
import pandas as pd
import numpy as np
import array

# %%
indexPanda = pd.Series([])
indexList = []

# %%
s1 = np.zeros((335,3))

# %%
s1[:] = [None]

# %%
list = pd.read_csv("c:/MachineLearningWork/tva_output.csv")

# %%
list
# Out:
#        Index Timestamp  Server  Tactic   Latency  Cost  Reliability  \
# 0          1   32:53.4       1       1  1.716679  15.9            1
# 1          2   33:01.9       1       2  8.534772  12.3            1
# 2          3   33:02.1       1       3  0.176431  28.8            1
# 3          4   33:08.5       1       4  6.426049  26.7            1
# 4          5   33:17.9       1       5  9.365804   2.1            1
# ...      ...       ...     ...     ...       ...   ...          ...
# 92255  92256   52:24.8       1       4  6.485255  25.7            1
# 92256  92257   52:25.1       1       5  0.293175  25.4            1
# 92257  92258   52:31.9       2       1  1.891588   5.4            1
# 92258  92259   52:35.4       2       2  3.508379  25.4            1
# 92259  92260   52:35.6       2       3  0.174014  26.4            1
#
#         TotalCost  Predicted Latency  Predicted Total Cost  Hours
# 0       27.295194                NaN                   NaN      0
# 1      104.977698                NaN                   NaN      0
# 2        5.081218                NaN                   NaN      0
# 3      171.575495                NaN                   NaN      0
# 4       19.668189                NaN                   NaN      0
# ...           ...                ...                   ...    ...
# 92255  166.671054                NaN                   NaN    117
# 92256    7.446657                NaN                   NaN    117
# 92257   10.214578                NaN                   NaN    117
# 92258   89.112838                NaN                   NaN    117
# 92259    4.593966                NaN                   NaN    117
#
# [92260 rows x 11 columns]

# %%
list.iloc[:, 3]
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#         ..
# 92255    4
# 92256    5
# 92257    1
# 92258    2
# 92259    3
# Name: Tactic, Length: 92260, dtype: int64

# %%
index = list.iloc[:, 0]
hours = list.iloc[:, 10]
latency = list.iloc[:, 4]
cost = list.iloc[:,7]
rel = list.iloc[:,6]
server1 = list.iloc[:,2]
#server2 = list.iloc[:,15]
#server3 = list.iloc[:,16]
#server4 = list.iloc[:,17]
#server5 = list.iloc[:,18]
#server6 = list.iloc[:,19]
#server7 = list.iloc[:,20]
#server8 = list.iloc[:,21]
tactic1 = list.iloc[:,3]
#tactic2 = list.iloc[:,23]
#tactic3 = list.iloc[:,24]
#tactic4 = list.iloc[:,25]
#tactic5 = list.iloc[:,26]

# %%
size = len(index)

# %%
max = hours[size-1]

# %%
prediction = np.zeros((size,1))

# %%
s1 = np.zeros((max,3))
s1[:] = 1
ii = 1
iii = 0
hourcheck = 1
sumS1l = 0
sumS1c = 0
countTimes = 1
n = 0
for j in range(0,size-1):
    if tactic1[j] == 1 and server1[j] == 1:
  #  if tactic1[j] == 2:
    #manually changed along with the save file. 
        
        if rel[j] and hours[j] == n:
            sumS1l = sumS1l + latency[j]
            sumS1c = sumS1c + cost[j]
            countTimes = countTimes + 1
            
        if hours[j] > n:
            s1[(n,0)] = n
            s1[(n,1)] = sumS1l / countTimes
            s1[(n,2)] = sumS1c / countTimes
            n = n + 1
            sumS1l = latency[j]
            sumS1c = cost[j]
#        [ 59.        ,   1.06604823,   8.24745637],
#        [ 60.        ,   1.08210036,   8.70582784],
#        [ 61.        ,   0.99965814,   8.33056384],
#        [ 62.        ,   1.10787564,   8.30689396],
#        [ 63.        ,   1.129576  ,   8.74791636],
#        [ 64.        ,   0.96984651,   8.4146779 ],
#        [ 65.        ,   1.57661012,   9.6640987 ],
#        [ 66.        ,   0.90151407,   8.48912612],
#        [ 67.        ,   1.36192255,   8.34266868],
#        [ 68.        ,   1.07453575,   8.39991184],
#        [ 69.        ,   1.22608971,   8.36931898],
#        [ 70.        ,   1.63100894,   8.89570856],
#        [ 71.        ,   0.80488586,   7.7522511 ],
#        [ 72.        ,   1.05218568,   8.40113719],
#        [ 73.        ,   1.05065704,   8.24738274],
#        [ 74.        ,   1.21002435,   8.98965743],
#        [ 75.        ,   0.86955819,   8.51827598],
#        [ 76.        ,   1.01571862,   8.42634789],
#        [ 77.        ,   0.7627117 ,   7.80341248],
#        [ 78.        ,   0.92325669,   8.11200507],
#        [ 79.        ,   0.52327555,   7.87698594],
#        [ 80.        ,   1.1875686 ,   8.71512051],
#        [ 81.        ,   0.97001239,   8.47092242],
#        [ 82.        ,   1.62971144,   9.4756137 ],
#        [ 83.        ,   0.81310057,   8.45901404],
#        [ 84.        ,   1.2760003 ,   8.96508024],
#        [ 85.        ,   1.01147382,   8.71646402],
#        [ 86.        ,   1.40262043,   9.25005482],
#        [ 87.        ,   1.69899594,   9.53222492],
#        [ 88.        ,   1.21010442,   8.59647243],
#        [ 89.        ,   0.97181699,   8.20117691],
#        [ 90.        ,   1.35941714,   8.35391651],
#        [ 91.        ,   1.62766531,   8.4574223 ],
#        [ 92.        ,   0.92201573,   8.19543253],
#        [ 93.        ,   1.26289141,   8.4671081 ],
#        [ 94.        ,   0.82005908,   8.0516374 ],
#        [ 95.        ,   0.96722153,   8.17493495],
#        [ 96.        ,   0.99399493,   8.15411595],
#        [ 97.        ,   1.22869873,   8.55576501],
#        [ 98.        ,   1.30894816,   8.60569014],
#        [ 99.        ,   1.66736059,   8.88550519],
#        [100.        ,   1.00629154,   8.11447634],
#        [101.        ,   1.74888532,   8.85739103],
#        [102.        ,   0.91661007,   8.09339245],
#        [103.        ,   1.25603998,   8.48033385],
#        [104.        ,   0.84091864,   8.37212716],
#        [105.        ,   1.08087384,   8.3003527 ],
#        [106.        ,   1.15900655,   8.27575131],
#        [107.        ,   1.00424659,   8.25094443],
#        [108.        ,   0.99304609,   8.0378999 ],
#        [109.        ,   1.09051233,   8.47948666],
#        [110.        ,   1.11463733,   8.49719001],
#        [111.        ,   0.89536923,   8.10964074],
#        [112.        ,   1.72489871,   9.42260603],
#        [113.        ,   1.14916549,   8.42435578],
#        [114.        ,   1.42333576,   8.75210012],
#        [115.        ,   1.35277144,   9.04103051],
#        [116.        ,   0.87974381,   8.28984442],
#        [  1.        ,   1.        ,   1.        ]])

# %%
np.savetxt("s1t1.csv", s1, delimiter=",")
