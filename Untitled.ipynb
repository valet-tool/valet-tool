# %%
import sklearn
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv("./One_hot_with_normalisation.csv")
y_data =

# %%
X_train, X_test = train_test_split(data,test_size=0.2, shuffle=False)

# %%
X_train.to_csv("normalizedXTrain.csv")
X_test.to_csv("normalizedXTest.csv")

# %%
X_test.to_csv("normalizedXTest.csv")X_test
# Out:
#        Unnamed: 0     Hours   Minutes   Seconds   Latency      Cost  \
# 45953       45953  0.695652  0.440678  0.080522  0.005321  0.274131
# 45954       45954  0.695652  0.440678  0.109898  0.001634  0.321750
# 45955       45955  0.695652  0.440678  0.110321  0.000023  0.256113
# 45956       45956  0.695652  0.440678  0.724928  0.034535  0.323037
# 45957       45957  0.695652  0.440678  0.729126  0.000235  0.324324
# 45958       45958  0.695652  0.457627  0.444336  0.040285  0.037323
# 45959       45959  0.695652  0.457627  0.479083  0.001932  0.330759
# 45960       45960  0.695652  0.457627  0.479681  0.000033  0.342342
# 45961       45961  0.695652  0.474576  0.096079  0.034732  0.329472
# 45962       45962  0.695652  0.474576  0.100332  0.000238  0.326898
# 45963       45963  0.695652  0.474576  0.644311  0.030567  0.047619
# 45964       45964  0.695652  0.474576  0.675998  0.001762  0.323037
# 45965       45965  0.695652  0.474576  0.676375  0.000021  0.320463
# ...
